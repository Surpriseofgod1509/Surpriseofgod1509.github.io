# %%
import sys
import os
# This forces the notebook to look in its current folder for other files
sys.path.append(os.path.abspath('')) 

# Importing the built-in unittest library to run our automated unit tests
import unittest

# ... rest of your code ...# Importing the built-in unittest library to run our automated unit tests
import unittest

# Importing the specific functions we fixed earlier from our temperature converter program
# Make sure the temperature_converter_FIXED.py file is in the same folder as this script
from temperature_converter_FIXED import celsius_to_fahrenheit, fahrenheit_to_celsius

# Creating a test class that inherits from unittest.TestCase so the system knows it's a test suite
class TestTemperatureConverter(unittest.TestCase):

    # --- Testing the Celsius to Fahrenheit conversion logic ---
    def test_celsius_to_fahrenheit(self):
        
        # Testing freezing point: 0 degrees Celsius should exactly equal 32 degrees Fahrenheit
        self.assertEqual(celsius_to_fahrenheit(0), 32)
        
        # Testing boiling point: 100 degrees Celsius should exactly equal 212 degrees Fahrenheit
        self.assertEqual(celsius_to_fahrenheit(100), 212)
        
        # Testing negative boundary: -40 is the unique point where both temperature scales are equal
        self.assertEqual(celsius_to_fahrenheit(-40), -40)

    # --- Testing the Fahrenheit to Celsius conversion logic ---
    def test_fahrenheit_to_celsius(self):
        
        # Testing freezing point backwards: 32 degrees Fahrenheit should equal 0 degrees Celsius
        self.assertEqual(fahrenheit_to_celsius(32), 0)
        
        # Testing boiling point backwards: 212 degrees Fahrenheit should equal 100 degrees Celsius
        self.assertEqual(fahrenheit_to_celsius(212), 100)
        
        # Testing negative boundary backwards: -40 Fahrenheit should equal -40 Celsius
        self.assertEqual(fahrenheit_to_celsius(-40), -40)

# This block checks if the script is being run directly (like clicking run in VS Code)
# If it is, it executes all the unit tests we defined above
if __name__ == '__main__':
    unittest.main()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 14
#      10 import unittest
#      12 # Importing the specific functions we fixed earlier from our temperature converter program
#      13 # Make sure the temperature_converter_FIXED.py file is in the same folder as this script
# ---> 14 from temperature_converter_FIXED import celsius_to_fahrenheit, fahrenheit_to_celsius
#      16 # Creating a test class that inherits from unittest.TestCase so the system knows it's a test suite
#      17 class TestTemperatureConverter(unittest.TestCase):
#      18
#      19     # --- Testing the Celsius to Fahrenheit conversion logic ---
#
# ModuleNotFoundError: No module named 'temperature_converter_FIXED'
